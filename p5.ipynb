# %%
import random

POPULATION_SIZE = 100
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
TARGET = "I love GeeksforGeeks"

class Individual(object):
    def __init__(self, chromosome):
        self.chromosome = chromosome
        self.fitness = self.cal_fitness()

    @classmethod
    def mutated_genes(cls):
        global GENES
        gene = random.choice(GENES)
        return gene

    @classmethod
    def create_gnome(cls):
        global TARGET
        gnome_len = len(TARGET)
        return [cls.mutated_genes() for _ in range(gnome_len)]

    def mate(self, par2):
        
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):

            prob = random.random()
            if prob < 0.45:
                child_chromosome.append(gp1)
            elif prob < 0.90:
                child_chromosome.append(gp2)
            else:
                child_chromosome.append(self.mutated_genes())
        return Individual(child_chromosome)

    def cal_fitness(self):
    
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt:
                fitness += 1
        return fitness

# Driver code
def main():
    global POPULATION_SIZE

    generation = 1
    found = False
    population = []

    for _ in range(POPULATION_SIZE):
        gnome = Individual.create_gnome()
        population.append(Individual(gnome))

    while not found:
        population = sorted(population, key=lambda x: x.fitness)
        if population[0].fitness <= 0:
            found = True
            break

        new_generation = []
        s = int((10 * POPULATION_SIZE) / 100)
        new_generation.extend(population[:s])
        s = int((90 * POPULATION_SIZE) / 100)
        for _ in range(s):
            parent1 = random.choice(population[:50])
            parent2 = random.choice(population[:50])
            child = parent1.mate(parent2)
            new_generation.append(child)

        population = new_generation

        print("Generation: {}\tString: {}\tFitness: {}".format(
            generation,
            "".join(population[0].chromosome),
            population[0].fitness))

        generation += 1

    print("Generation: {}\tString: {}\tFitness: {}".format(
        generation,
        "".join(population[0].chromosome),
        population[0].fitness))

if __name__ == '__main__':
    main()
# Out:
# Generation: 1	String: z 1OT[4j]k8&f:sJ.4k 	Fitness: 17
# Generation: 2	String: z 1OT[4j]k8&f:sJ.4k 	Fitness: 17
# Generation: 3	String: z 1OT[4j]k8&f:sJ.4k 	Fitness: 17
# Generation: 4	String: z .OTcty[ogsf:s .4kQ	Fitness: 16
# Generation: 5	String: I fGRku6[fksf6dc])YQ	Fitness: 15
# Generation: 6	String: I fGRku6[fksf6dc])YQ	Fitness: 15
# Generation: 7	String: I fyRev6[Ak:fSrc9Qbd	Fitness: 14
# Generation: 8	String: y fBGe$6:OksfSrReQ$d	Fitness: 13
# Generation: 9	String: y ,hTetu{ohs[orGeQ=s	Fitness: 12
# Generation: 10	String: I UVRevy[eksAoDGe[Yq	Fitness: 11
# Generation: 11	String: I 4L=e$PeeM7forGeQes	Fitness: 9
# Generation: 12	String: I 4L=e$PeeM7forGeQes	Fitness: 9
# Generation: 13	String: I 4L=e$PeeM7forGeQes	Fitness: 9
# Generation: 14	String: I 4L=e$PeeM7forGeQes	Fitness: 9
# Generation: 15	String: I 3V]e y1eksforG]"=s	Fitness: 8
# Generation: 16	String: I 3V]e y1eksforG]"=s	Fitness: 8
# Generation: 17	String: I UV=evyeeksforGe3es	Fitness: 7
# Generation: 18	String: I 3V]e yeeksforGe3=s	Fitness: 6
# Generation: 19	String: I 3V]e yeeksforGe3=s	Fitness: 6
# Generation: 20	String: I 3V]e yeeksforGe3=s	Fitness: 6
# Generation: 21	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 22	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 23	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 24	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 25	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 26	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 27	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 28	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 29	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 30	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 31	String: I UVee veeksforGe3ks	Fitness: 5
# Generation: 32	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 33	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 34	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 35	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 36	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 37	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 38	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 39	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 40	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 41	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 42	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 43	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 44	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 45	String: I lV]e yeeksforGeKks	Fitness: 4
# Generation: 46	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 47	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 48	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 49	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 50	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 51	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 52	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 53	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 54	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 55	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 56	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 57	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 58	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 59	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 60	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 61	String: I lHAe yeeksforGeeks	Fitness: 3
# Generation: 62	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 63	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 64	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 65	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 66	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 67	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 68	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 69	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 70	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 71	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 72	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 73	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 74	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 75	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 76	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 77	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 78	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 79	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 80	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 81	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 82	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 83	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 84	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 85	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 86	String: I lHve yeeksforGeeks	Fitness: 2
# Generation: 87	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 88	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 89	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 90	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 91	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 92	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 93	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 94	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 95	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 96	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 97	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 98	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 99	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 100	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 101	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 102	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 103	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 104	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 105	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 106	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 107	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 108	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 109	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 110	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 111	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 112	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 113	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 114	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 115	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 116	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 117	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 118	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 119	String: I lrve GeeksforGeeks	Fitness: 1
# Generation: 120	String: I love GeeksforGeeks	Fitness: 0
